# %%
pip install statsmodels
# Out:
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------  9.4/9.6 MB 73.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 54.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    --------- ------------------------------ 11.0/46.2 MB 57.5 MB/s eta 0:00:01
#    --------------- ------------------------ 18.4/46.2 MB 48.2 MB/s eta 0:00:01
#    -------------------------- ------------- 30.7/46.2 MB 49.9 MB/s eta 0:00:01
#    ------------------------------------- -- 43.0/46.2 MB 53.6 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 46.0 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/3 [scipy]
#    ---------------------------------------- 0/3 [scipy]
#    ---------------------------------------- 0/3 [scipy]
#    ---------------------------------------- 0/3 [scipy]
#    ---------------------------------------- 0/3 [scipy]
# ...

# %%
# !pip install statsmodels

# %%
import statsmodels.api as sm

# %%
conda install statsmodels
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_line_magic('conda', 'install statsmodels')
#
# File ~\miniconda3\envs\tf_env\lib\site-packages\IPython\core\interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\miniconda3\envs\tf_env\lib\site-packages\IPython\core\magics\packaging.py:30, in is_conda_environment.<locals>.wrapper(*args, **kwargs)
# ...

# %%
conda install statsmodels
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_line_magic('conda', 'install statsmodels')
#
# File ~\miniconda3\envs\tf_env\lib\site-packages\IPython\core\interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\miniconda3\envs\tf_env\lib\site-packages\IPython\core\magics\packaging.py:30, in is_conda_environment.<locals>.wrapper(*args, **kwargs)
# ...

# %%
# %pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import numpy as np

df = pd.read_csv(r"C:\Users\kelly\OneDrive\Área de Trabalho\MIS581 Capstone\Mod 2\Hotel_booking\hotel_booking.csv")

df['total_stay'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']
df['total_guests'] = df['adults'] + df['children'] + df['babies']

data = df[['adr', 'lead_time', 'total_stay', 'total_guests']].dropna()

X = data[['lead_time', 'total_stay', 'total_guests']]
y = data['adr']

model = LinearRegression()
model.fit(X, y)

print("Intercept:", model.intercept_)
print("Coefficients:")
for name, coef in zip(X.columns, model.coef_):
    print(name, ":", coef)

predictions = model.predict(X)
print("R-squared:", r2_score(y, predictions))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.linear_model import LinearRegression
#       3 from sklearn.metrics import r2_score
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# %pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ----------------------- ---------------- 6.6/11.2 MB 66.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 49.7 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [joblib]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\kelly\OneDrive\Área de Trabalho\MIS581 Capstone\Mod 2\Hotel_booking\hotel_booking.csv")

df['total_stay'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']
df['total_guests'] = df['adults'] + df['children'] + df['babies']

print(df[['adr', 'lead_time', 'total_stay', 'total_guests']].describe())
print(df[['adr', 'lead_time', 'total_stay', 'total_guests']].corr())
# Out:
#                  adr      lead_time     total_stay   total_guests
# count  119390.000000  119390.000000  119390.000000  119386.000000
# mean      101.831122     104.011416       3.427900       1.968229
# std        50.535790     106.863097       2.557439       0.722400
# min        -6.380000       0.000000       0.000000       0.000000
# 25%        69.290000      18.000000       2.000000       2.000000
# 50%        94.575000      69.000000       3.000000       2.000000
# 75%       126.000000     160.000000       4.000000       2.000000
# max      5400.000000     737.000000      69.000000      55.000000
#                    adr  lead_time  total_stay  total_guests
# adr           1.000000  -0.063077    0.067945      0.368144
# lead_time    -0.063077   1.000000    0.157167      0.072279
# total_stay    0.067945   0.157167    1.000000      0.115473
# total_guests  0.368144   0.072279    0.115473      1.000000

# %%
import matplotlib.pyplot as plt

df['adr'].hist()
plt.title("Distribution of ADR")
plt.xlabel("ADR")
plt.ylabel("Frequency")
plt.show()

# %%
# %pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import statsmodels.api as sm

df = pd.read_csv(r"C:\Users\kelly\OneDrive\Área de Trabalho\MIS581 Capstone\Mod 2\Hotel_booking\hotel_booking.csv")

df['total_stay'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']
df['total_guests'] = df['adults'] + df['children'] + df['babies']

data = df[['adr', 'lead_time', 'total_stay', 'total_guests']].dropna()

X = data[['lead_time', 'total_stay', 'total_guests']]
X = sm.add_constant(X)
y = data['adr']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    adr   R-squared:                       0.145
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     6759.
# Date:                Sat, 02 May 2026   Prob (F-statistic):               0.00
# Time:                        15:54:40   Log-Likelihood:            -6.2835e+05
# No. Observations:              119386   AIC:                         1.257e+06
# Df Residuals:                  119382   BIC:                         1.257e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           52.8337      0.425    124.257      0.000      52.000      53.667
# ...
